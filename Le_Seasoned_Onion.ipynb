# %% [markdown]
# <a href="https://colab.research.google.com/github/tuansydau/seasonedOnion/blob/master/Le_Seasoned_Onion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("le onion")
# Out:
# le onion

# %%
print("website")
# Out:
# website

# %%
print("suh dud")
# Out:
# suh dud
